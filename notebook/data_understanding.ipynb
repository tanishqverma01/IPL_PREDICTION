# %%
import os

print("Current Directory:")
print(os.getcwd())

print("\nFiles/Folders:")
print(os.listdir())
# Out:
# Current Directory:
# d:\IPL_PROJECT\notebook
#
# Files/Folders:
# ['data_understanding.ipynb', 'deliveries.csv', 'eda.ipynb', 'ipl_new.csv', 'matches.csv']

# %%
import pandas as pd

matches = pd.read_csv("matches.csv")
deliveries = pd.read_csv("deliveries.csv")

# %%
matches.head()
# Out:
#    match_id            date                               venue team1 team2  \
# 0         1  March 28, 2026   M. Chinnaswamy Stadium, Bangalore   RCB   SRH
# 1         2  March 29, 2026            Wankhede Stadium, Mumbai    MI   KKR
# 2         3  March 30, 2026         Barsapara Stadium, Guwahati    RR   CSK
# 3         4  March 31, 2026  New PCA Cricket Stadium, Mullanpur  PBKS    GT
# 4         5  April 01, 2026      Ekana Cricket Stadium, Lucknow   LSG    DC
#
#     stage toss_winner toss_decision  first_ings_score  first_ings_wkts  ...  \
# 0  League         RCB          Bowl             201.0              9.0  ...
# 1  League          MI          Bowl             220.0              4.0  ...
# 2  League          RR          Bowl             127.0             10.0  ...
# 3  League        PBKS          Bowl             162.0              6.0  ...
# 4  League          DC          Bowl             141.0             10.0  ...
#
# ...

# %%
deliveries.head()
# Out:
#    match_no          date         stage                             venue  \
# 0         1  Mar 28, 2026  League stage  M.Chinnaswamy Stadium, Bengaluru
# 1         1  Mar 28, 2026  League stage  M.Chinnaswamy Stadium, Bengaluru
# 2         1  Mar 28, 2026  League stage  M.Chinnaswamy Stadium, Bengaluru
# 3         1  Mar 28, 2026  League stage  M.Chinnaswamy Stadium, Bengaluru
# 4         1  Mar 28, 2026  League stage  M.Chinnaswamy Stadium, Bengaluru
#
#   batting_team bowling_team  innings  over          striker       bowler  \
# 0          SRH          RCB        1   0.1      Travis Head  Jacob Duffy
# 1          SRH          RCB        1   0.2      Travis Head  Jacob Duffy
# 2          SRH          RCB        1   0.3  Abhishek Sharma  Jacob Duffy
# 3          SRH          RCB        1   0.4  Abhishek Sharma  Jacob Duffy
# 4          SRH          RCB        1   0.5  Abhishek Sharma  Jacob Duffy
#
#    runs_of_bat  extras  wide  legbyes  byes  noballs wicket_type  \
# ...

# %%
matches.tail()
# Out:
#     match_id            date                             venue team1 team2  \
# 34        35  April 25, 2026       Arun Jaitley Stadium, Delhi    DC  PBKS
# 35        36  April 25, 2026    Sawai Mansingh Stadium, Jaipur    RR   SRH
# 36        37  April 26, 2026  Narendra Modi Stadium, Ahmedabad    GT   CSK
# 37        38  April 26, 2026    Ekana Cricket Stadium, Lucknow   LSG   KKR
# 38        39  April 27, 2026       Arun Jaitley Stadium, Delhi    DC   RCB
#
#      stage toss_winner toss_decision  first_ings_score  first_ings_wkts  ...  \
# 34  League          DC           Bat             264.0              2.0  ...
# 35  League         SRH          Bowl             228.0              6.0  ...
# 36  League          GT          Bowl             158.0              7.0  ...
# 37  League         LSG          Bowl             155.0              7.0  ...
# 38  League         RCB          Bowl              75.0             10.0  ...
#
# ...

# %%
deliveries.tail()
# Out:
#        match_no          date  stage                             venue  \
# 17472        74  May 31, 2026  Final  Narendra Modi Stadium, Ahmedabad
# 17473        74  May 31, 2026  Final  Narendra Modi Stadium, Ahmedabad
# 17474        74  May 31, 2026  Final  Narendra Modi Stadium, Ahmedabad
# 17475        74  May 31, 2026  Final  Narendra Modi Stadium, Ahmedabad
# 17476        74  May 31, 2026  Final  Narendra Modi Stadium, Ahmedabad
#
#       batting_team bowling_team  innings  over        striker       bowler  \
# 17472          RCB           GT        2  17.2    Virat Kohli  Arshad Khan
# 17473          RCB           GT        2  17.3  Jitesh Sharma  Arshad Khan
# 17474          RCB           GT        2  17.4  Jitesh Sharma  Arshad Khan
# 17475          RCB           GT        2  17.5    Virat Kohli  Arshad Khan
# 17476          RCB           GT        2  17.6    Virat Kohli  Arshad Khan
#
#        runs_of_bat  extras  wide  legbyes  byes  noballs wicket_type  \
# ...

# %%
matches.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             39 non-null     int64
#  1   date                 39 non-null     str
#  2   venue                39 non-null     str
#  3   team1                39 non-null     str
#  4   team2                39 non-null     str
#  5   stage                39 non-null     str
#  6   toss_winner          39 non-null     str
#  7   toss_decision        39 non-null     str
#  8   first_ings_score     38 non-null     float64
#  9   first_ings_wkts      38 non-null     float64
#  10  second_ings_score    38 non-null     float64
#  11  second_ings_wkts     38 non-null     float64
#  12  match_result         39 non-null     str
#  13  match_winner         38 non-null     str
#  14  wb_runs              15 non-null     float64
#  15  wb_wickets           22 non-null     float64
# ...

# %%
deliveries.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17477 entries, 0 to 17476
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_no          17477 non-null  int64
#  1   date              17477 non-null  str
#  2   stage             17477 non-null  str
#  3   venue             17477 non-null  str
#  4   batting_team      17477 non-null  str
#  5   bowling_team      17477 non-null  str
#  6   innings           17477 non-null  int64
#  7   over              17477 non-null  float64
#  8   striker           17477 non-null  str
#  9   bowler            17477 non-null  str
#  10  runs_of_bat       17477 non-null  int64
#  11  extras            17477 non-null  int64
#  12  wide              17477 non-null  int64
#  13  legbyes           17477 non-null  int64
#  14  byes              17477 non-null  int64
#  15  noballs           17477 non-null  int64
#  16  wicket_type       879 non-null    str
# ...

# %%
matches.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  39.000000         38.000000        38.000000          38.000000
# mean   20.000000        190.526316         6.289474         175.500000
# std    11.401754         39.394565         2.470451          39.747684
# min     1.000000         75.000000         2.000000          77.000000
# 25%    10.500000        159.750000         4.250000         159.250000
# 50%    20.000000        197.000000         6.000000         180.000000
# 75%    29.500000        215.000000         8.000000         203.750000
# max    39.000000        264.000000        10.000000         265.000000
#
#        second_ings_wkts     wb_runs  wb_wickets  balls_left   highscore
# count         38.000000   15.000000   22.000000   38.000000   38.000000
# mean           6.052632   41.666667    5.772727   10.684211   79.447368
# std            2.670635   30.658643    1.477830   15.773918   24.521031
# ...

# %%
print("total matches:",matches.shape[0])
# Out:
# total matches: 39

# %%
teams = pd.concat([matches['team1'],
                   matches['team2']]).unique()
print("Total teams:",len(teams))
print(teams)
# Out:
# Total teams: 10
# <ArrowStringArray>
# ['RCB', 'MI', 'RR', 'PBKS', 'LSG', 'KKR', 'CSK', 'DC', 'GT', 'SRH']
# Length: 10, dtype: str

# %%
players = deliveries['striker'].unique()
print("total players:",len(players))
# Out:
# total players: 177

# %%
print(players[:20])
# Out:
# <ArrowStringArray>
# [     'Travis Head',  'Abhishek Sharma',     'Ishan Kishan',
#      'Nitish Reddy', 'Heinrich Klaasen',      'Salil Arora',
#      'Aniket Verma',      'Harsh Dubey',    'Harshal Patel',
#       'David Payne',   'Jaydev Unadkat',        'Phil Salt',
#  'Devdutt Padikkal',      'Virat Kohli',    'Rajat Patidar',
#     'Jitesh Sharma',        'Tim David',   'Ajinkya Rahane',
#        'Finn Allen',    'Cameron Green']
# Length: 20, dtype: str

# %%
matches.isnull().sum()
# Out:
# match_id                0
# date                    0
# venue                   0
# team1                   0
# team2                   0
# stage                   0
# toss_winner             0
# toss_decision           0
# first_ings_score        1
# first_ings_wkts         1
# second_ings_score       1
# second_ings_wkts        1
# match_result            0
# match_winner            1
# wb_runs                24
# wb_wickets             17
# balls_left              1
# player_of_the_match     1
# top_scorer              1
# highscore               1
# best_bowling            1
# best_bowling_figure     1
# super_over_match        0
# dtype: int64

# %%
deliveries.isnull().sum()
# Out:
# match_no                0
# date                    0
# stage                   0
# venue                   0
# batting_team            0
# bowling_team            0
# innings                 0
# over                    0
# striker                 0
# bowler                  0
# runs_of_bat             0
# extras                  0
# wide                    0
# legbyes                 0
# byes                    0
# noballs                 0
# wicket_type         16598
# player_dismissed    16602
# fielder             16791
# dtype: int64

# %%
print("Duplicate Rows in Matches:",
      matches.duplicated().sum())
# Out:
# Duplicate Rows in Matches: 0

# %%
print("Duplicate Rows in Deliveries:",
      deliveries.duplicated().sum())
# Out:
# Duplicate Rows in Deliveries: 0

# %%
print("="*50)

print("IPL DATASET SUMMARY")

print("="*50)

print("Total Matches:",
      matches.shape[0])

print("Total Teams:",
      len(pd.concat([
          matches['team1'],
          matches['team2']
      ]).unique()))

print("Total Players:",
      deliveries['striker'].nunique())

print("\nMissing Values in Matches:")
print(matches.isnull().sum())

print("\nMissing Values in Deliveries:")
print(deliveries.isnull().sum())

print("\nDuplicate Rows in Matches:",
      matches.duplicated().sum())

print("Duplicate Rows in Deliveries:",
      deliveries.duplicated().sum())
# Out:
# ...
# IPL DATASET SUMMARY
# ...
# Total Matches: 39
# Total Teams: 10
# Total Players: 177
#
# Missing Values in Matches:
# match_id                0
# date                    0
# venue                   0
# team1                   0
# team2                   0
# stage                   0
# toss_winner             0
# toss_decision           0
# first_ings_score        1
# first_ings_wkts         1
# second_ings_score       1
# second_ings_wkts        1
# match_result            0
# match_winner            1
# wb_runs                24
# wb_wickets             17
# balls_left              1
# player_of_the_match     1
# top_scorer              1
# highscore               1
# best_bowling            1
# best_bowling_figure     1
# super_over_match        0
# dtype: int64
#
# Missing Values in Deliveries:
# match_no                0
# date                    0
# stage                   0
# venue                   0
# batting_team            0
# bowling_team            0
# ...

# %%
matches.dropna
# Out:
# <bound method DataFrame.dropna of     match_id            date                                          venue  \
# 0          1  March 28, 2026              M. Chinnaswamy Stadium, Bangalore
# 1          2  March 29, 2026                       Wankhede Stadium, Mumbai
# 2          3  March 30, 2026                    Barsapara Stadium, Guwahati
# 3          4  March 31, 2026             New PCA Cricket Stadium, Mullanpur
# 4          5  April 01, 2026                 Ekana Cricket Stadium, Lucknow
# 5          6  April 02, 2026                          Eden Gardens, Kolkata
# 6          7  April 03, 2026                MA Chidambaram Stadium, Chennai
# 7          8  April 04, 2026                    Arun Jaitley Stadium, Delhi
# 8          9  April 04, 2026               Narendra Modi Stadium, Ahmedabad
# 9         10  April 05, 2026  Rajiv Gandhi International Stadium, Hyderabad
# 10        11  April 05, 2026              M. Chinnaswamy Stadium, Bangalore
# ...

# %%
matches['team1'] = matches['team1'].replace(
    'Delhi Daredevils',
    'Delhi Capitals'
)

# %%
matches.to_csv('ipl_new.csv', index=False)
